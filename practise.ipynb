# %%
from src.utils.util import *
from src.constants.github_data_constants import *
from src.constants import *
import os

# %%
def read_statewise_usersdata(self )-> pd.DataFrame:
    return read_from_csv(STATE_WISE_USERSDATA_FILE_NAME)

def filter_repository_data(self, repository) -> pd.DataFrame:
    
    test =  [
        {
        "full_repository_name": repo.get('full_name', None),
        "name": repo.get('name', None),
        "user_type":repo.get('owner', {}).get('type', None),

        "created_at":repo.get('created_at', None),
        "pushed_at":repo.get('pushed_at', None),
        "updated_at":repo.get('updated_at', None),

        "default_branch":repo.get('default_branch', None),
        "description":repo.get('description', None),

        "open_issues":repo.get('open_issues', None),
        "open_issues_count":repo.get('open_issues_count', None),

        "visibility":repo.get('visibility', None),
        "watchers":repo.get('watchers', None),
        "watchers_count":repo.get('watchers_count', None),

        "is_disabled":repo.get('disabled', False),
        "is_archieved":repo.get('archived', False),
        "languages_url":repo.get('languages_url', None),
        "contributors_url":repo.get('contributors_url', None)

        } 
        for repo in repository if repo is not None]
    return create_data_frame(test)

def get_contributors_count(self, df, col) ->list:
    count = []
    if col in df.columns:
        for url in df[col]:
                if url:
                    res = read_from_url(url)
                    if res.status_code == 200:
                        res = res.json()
                        if res:
                            if res and isinstance(res, list) and 'contributions' in res[0]:
                                    count.append(res[0]['contributions'])
                            else:
                                    count.append(0)
                        else:
                            count.append(0)
                    elif res.status_code == 403: break
                else: count.append(0)
    while len(count) < len(df):
        count.append(0)
    return count

def get_languages_count(self, df, col):
    temp = []
    if col in df.columns:
        for url in df[col]:
            res = read_from_url(url)
            if res.status_code == 200:
                res = res.json()
                if res:
                    temp.append(res)

            elif res.status_code == 403: break

    return create_data_frame(temp)

def merge_dataframes_row_col_wise(self, df1, df2):

    t3 = df2.T
    t3.reset_index(inplace=True)
    if 'index' in t3.columns:
        t3.rename(columns={'index': 'language'}, inplace=True)

    languages_long = t3.melt(id_vars='language', var_name='repo_index', value_name='language_count')
    languages_long['repo_index'] = languages_long['repo_index'].astype(int)

    df1 = df1.reset_index().rename(columns={'index': 'index_column'})
    
    merged_df = pd.merge(df1, languages_long, left_on='index_column', right_on='repo_index')

    merged_df.drop('index_column', axis=1, inplace=True)
    merged_df.drop('repo_index', axis=1, inplace=True)
    print("merging inside the function....DONE")

    current_time_stamp = get_current_time_stamp()

    dir_path = os.path.join(ROOT_DIR, DATASET_LOCATION, EXTERNAL_DATASET_DIRECTORY_NAME)

    os.makedirs(dir_path, exist_ok=True)

    file_name = STATE_WISE_USERSDATA_FILE_NAME

    write_to_csv(df=merged_df, file_path=join_paths(path1=dir_path, path2=file_name))
    return merged_df

def fetch_repos(self, username, state):
    
    ## Input: User Name, State Name
    ## Output: DataFrame with all the required details
    ## Description:
    # This function invokes the  HTTP GET Requests method, filters the respone and finally returns the response in a Data Frame.                     

    repos = read_from_url(f"{USERS_URL}/{username}/repos")
    if repos.status_code == 200:
        repos = repos.json()
        repos.extend([None] * (30 - len(repos)))

        df = self.filter_repository_data(repository=repos)
        df['user name'] = [username] * len(df) 
        df['state'] = [state] * len(df)
        df['contributions_count'] = self.get_contributors_count(df=df, col="contributors_url")
        temp_df = self.get_languages_count(df, 'languages_url')
        merged_df = self.merge_dataframes_row_col_wise(df, temp_df)
        return merged_df
    elif repos.status_code == 403:
            return merged_df
    else:
        raise Exception(status_code=repos.status_code, detail="Error fetching repositories")

# %%
import numpy as np
import pandas as pd
import os

def stratified_sample(df, sample_size, random_state=None):
    state_proportions = df['state'].value_counts(normalize=True)
    state_sample_sizes = np.rint(state_proportions * sample_size).astype(int)

    def sample_from_group(group):
        state = group.name
        n_samples = state_sample_sizes[state]
        return group.sample(n=n_samples, random_state=random_state)

    return df.groupby('state', group_keys=False).apply(sample_from_group)

def sample_users_data_with_stratified_sampling(raw_data_file_path: str, random_state=None):
    data = read_from_csv(file_path=raw_data_file_path)
    total_records = len(data)
    samples = {percent: {} for percent in SAMPLE_SIZES_PERCENTAGES}

    for percent in SAMPLE_SIZES_PERCENTAGES:
        sample_size = int(total_records * percent)
        samples[percent] = stratified_sample(df=data, sample_size=sample_size, random_state=random_state)
    
    directory_location = os.path.join(SAMPLED_USERS_DATASET_FILE_PATH, CURRENT_TIME_STAMP)
    create_directories(directories_path=directory_location)
    processed_dataset_with_time_stamp = directory_location

    for percent in SAMPLE_SIZES_PERCENTAGES:
        path = os.path.join(processed_dataset_with_time_stamp, f"samples_of_size_{int(percent*100)}_percentage.csv")
        write_to_csv(df=samples[percent], file_path=path)

# Example usage
# sample_users_data_with_stratified_sampling("path_to_your_file.csv", random_state=None)

# %%
# sample_users_data_with_stratified_sampling("D:\\DM Project\\Testing\\GitHubDataRetrieval\\data\\raw\\state_wise_user_names.csv")

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

def fetch_and_update(user_name, state_name):
    try:
        df1 = fetch_repos(username=user_name, state=state_name)
        if df1 is None:  # Check if df1 is None and handle it
            df1 = pd.DataFrame()
    except Exception as e:
        print(f"Error fetching data for {user_name}: {e}")
        df1 = pd.DataFrame()  # Ensure df1 is a DataFrame even in case of an exception

    return state_name, df1

def download_users_data( sample_fraction, file_path: str):
    sample_users_data_with_stratified_sampling(raw_data_file_path=file_path)

    subdirectories = os.listdir(SAMPLED_USERS_DATASET_FILE_PATH)

    subdirectories.sort(reverse=True)
    print(f"subdirectories in the sampled users folder are: {subdirectories}")

    latest_subdir = subdirectories[0] if subdirectories else None
    filtered_file_name = ""
    try:
        if latest_subdir:
            search_path = os.path.join(SAMPLED_USERS_DATASET_FILE_PATH, latest_subdir, f"samples_of_size_{sample_fraction}_percentage.csv")
            
            for file in glob.glob(search_path):
                filtered_file_name = file
                break
        else:
            raise CustomException(f"No files found in {SAMPLED_USERS_DATASET_FILE_PATH} directory")
    except Exception as e:
        raise CustomException(e, sys)
        
    print(f"Filtered file name: {filtered_file_name}")
    combined_df = read_from_csv(file_path= filtered_file_name)
    

    repos_dict = {}
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = {executor.submit(fetch_and_update, row['username'], row['state']): row for _, row in combined_df.iterrows()}

        for future in as_completed(futures):
            state_name, df1 = future.result()
            if not df1.empty:
                if state_name in repos_dict:
                    repos_dict[state_name] = pd.concat([repos_dict[state_name], df1], ignore_index=True)
                else:
                    repos_dict[state_name] = df1
    create_directories(REPOSITORY_DATA_FILE_DIRECTORY_NAME)
    combined_df = pd.DataFrame()
    for state, df in repos_dict.items():
        # You can add a 'state' column if it's not already in the DataFrame
        df['state'] = state
        combined_df = pd.concat([combined_df, df], ignore_index=True)

    combined_df.to_csv(REPOSITORY_DATA_FILE_PATH, index=False)

# %%
# from os import listdir
# from os.path import join
# import pandas as pd
# import glob

# def download_users_data(sample_fraction, file_path: str):
#     sample_users_data_with_stratified_sampling(raw_data_file_path=file_path)

#     subdirectories = os.listdir(SAMPLED_USERS_DATASET_FILE_PATH)

#     subdirectories.sort(reverse=True)
#     print(f"subdirectories in the sampled users folder are: {subdirectories}")

#     latest_subdir = subdirectories[0] if subdirectories else None
#     filtered_file_name = ""
    

#     if latest_subdir:
#         search_path = join(SAMPLED_USERS_DATASET_FILE_PATH, latest_subdir, f"samples_of_size_{sample_fraction}_percentage.csv")
#         filtered_file_name = next(glob.iglob(search_path), None)
#         if not filtered_file_name:
#             raise CustomException(f"No files found in {SAMPLED_USERS_DATASET_FILE_PATH} directory")
#     else:
#         raise CustomException(f"No subdirectories found in {SAMPLED_USERS_DATASET_FILE_PATH}")

#     print(f"Filtered file name: {filtered_file_name}")
#     combined_df = read_from_csv(file_path= filtered_file_name)
#     combined_df = combined_df[0:5]
#     print(combined_df)

#     # repos_dict = {}
#     # for _, row in combined_df.iterrows():
#     #     state_name, user_name = row['state'], row['username']
#     #     try:
#     #         df1 = fetch_repos(username=user_name, state=state_name)
#     #         if not df1.empty:
#     #             repos_dict.setdefault(state_name, []).append(df1)
#     #     except Exception as e:
#     #         print(f"Error fetching data for {user_name}: {e}")

#     # for state, df_list in repos_dict.items():
#     #     repos_dict[state] = pd.concat(df_list, ignore_index=True)

#     # final_df = pd.concat(repos_dict.values(), ignore_index=True)
#     # create_directories(REPOSITORY_DATA_FILE_DIRECTORY_NAME)
#     # final_df.to_csv(REPOSITORY_DATA_FILE_PATH, index=False)

# # Example usage
# # download_users_data(3, "path_to_your_file.csv")

# %%
download_users_data(1, "D:\\DM Project\\Testing\\GitHubDataRetrieval\\data\\raw\\state_wise_user_names.csv")
# Out:
# subdirectories in the sampled users folder are: ['24-11-23_13-30-23']
# Filtered file name: d:\DM Project\Testing\GitHubDataRetrieval\data\processed\sampled_user_names_files\24-11-23_13-30-23\samples_of_size_1_percentage.csv
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# Error fetching data for sunshinemu: cannot access local variable 'merged_df' where it is not associated with a value
# merging inside the function....DONE
# Error fetching data for shanicegipson: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jwolf76dev: cannot access local variable 'merged_df' where it is not associated with a value
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# merging inside the function....DONE
# Error fetching data for jimbucktoo: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for nathanfrancy: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Evanjm7: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for MrGate: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Saphrym: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for BionicOven28: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jacobrrichardson41: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Eldritchhat: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for claydoh95: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for uhzees: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Nandeshwar-Verma: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for kazimnoori: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for thisisyou33-publishing-networks: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Sniper-E: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for w0437353: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sjackson01: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Londale35: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Olivia-Cheung: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Nate191941: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tcaviness: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for N8-Des: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for maniginam: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for kynian: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Camden-McKenzie: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for iamjoshfrank: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for StevenSeiden: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ablack3: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for custerc: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jlbutler: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for indiehd: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for henbagle: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for leahwiley: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for dcooper16: cannot access local variable 'merged_df' where it is not associated with a valueError fetching data for bmzhu2: cannot access local variable 'merged_df' where it is not associated with a value
#
# Error fetching data for yoowook1207: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for lena0429: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jesserwright: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for smekosh: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for rbozal1: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for devilsangel: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for haffinnih: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for SubhaBrataHowlader: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tjnine: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Ishan2601: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for davestgermain: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for michaellu2019: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ChungYi347: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for LarryJiang134: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Polkm: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sgivan: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ZelnickB: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bgrrtt: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tjconnelly: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for strykeforce: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sheldor1510: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for arkrusade: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for djphazer: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for emster7013: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sotch-pr35mac: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for relative2: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for LiamKing1: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Firenza: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for dschuurman: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tylerholien: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for MarkLeMerise: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jmkoch: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for calebroseland: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for FiniteSingularity: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tsaitsai: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for lurchinms: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bobbywarner: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cowboygneox: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for athaeryn: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for brent901: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for TerranceJay: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for memmzer: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for EricM96: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for chasebaker288: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for DreshonTheGreat: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for paulAriri: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for gattodigital: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for gabe31415: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ftcteam14236: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for peacefulcheast31: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tscales: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jsieber: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bricurr: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for DragoLuke: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tylerwmarrs: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for eazyd: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for EdwardVenaglia: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for eXtremeGravityInstitute: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for FreshlyCutWax: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for zschumacher: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for GoldenRomanov: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Saint-Louis-University: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for stratemeyerjw: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for wrdaigle: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for req24028: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for JesseFoxhoven: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jenkr55: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for rachel-holton-burnett: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for c1oneman: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jacobmelcher: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for TobiasKundig: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for meescool: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for TylerAkrs: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for amylhampton: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bjcooper: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for natevek: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for eventgraph: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Senaith: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for SOPFTF: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for mdokeefe: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for auxsophia: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for leaderdescar: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for rscafidi: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for JulissaC: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for micalez: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for mklement0: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for onsclom: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for chkp-ccurrier: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for AnnStonely: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for RedSoxFan: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jacobgithub: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for YWangXJ: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Fentana: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for suprattle: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for margoburns: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for universalweb: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for JJ27: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for willgeorgejr: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for DarrenTapp: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for rbielak: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Lamadrid-Mike: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for virjog: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Mischief1026: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bdurham227: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for concept-inversion: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for g34dirty4: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for haixpham: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for BradleyLWood: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sanujsriv: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for GhostViz: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for hollyhan: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for JohnWBriggs: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for faithcomesbyhearing: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Actuarybrad: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for peggyrayzis: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Cons-Cat: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cyoon1729: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for TorresChristian1: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for alexgolec: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for D-Freitas: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sergeichestakov: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for john-maybee: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for DionysiosB: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for amallia: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for shnhrrsn: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for rviscomi: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for BrickOHeads: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for aceofbassgreg: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for benesch: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for roshani98: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jduelfer: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for gfxden: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for anishpatel: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for johnchoi96: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for runlevel-six: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Palme412: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Clevelandjr: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Jgobeille: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ChrisMKindred: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cads-unc: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for pwrliang: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for HanClinto: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for RavSalgado: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for mletterle: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cromwellryan: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for mikebrown75: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for mikeyp: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for derrickaustin: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cdrischler: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for zbream: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for birdwell: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for claytonflesher: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for killrazor: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tayloradam1999: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for AjayGanesh02: cannot access local variable 'merged_df' where it is not associated with a valueError fetching data for ashleyrcoffey: cannot access local variable 'merged_df' where it is not associated with a value
#
# Error fetching data for samlupton: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for nlynchjo: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jsween: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for alex-fok: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jhaubrich: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jbleyleSF: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for vestoj: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for robertrowe1013: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for vpitoscia: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Windowmac: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for eMapR: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for connorlay: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for laurelayounis: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sumeyaali: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for treckstar: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for barefootdeveloper: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for DomreyCS: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bashtech: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for sylversurfer: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for amrutharamesh: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for TammyLaforest: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for imbaguanxin: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ZachBaird: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Fenrisulvur: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for v11ncent: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cherubear: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ar-valdez: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for gokulPushparaj: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for PGilbertSchmitt: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for areou: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for mmisanko: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for chmaynard: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for RobSchul: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for arellanoc: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for julio-molina: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for perezsergioace: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for reprosser: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for reneerich70: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for NathanielRand: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for MonteKrysto: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for xXEthyleneXx: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for chasehenry862: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ElliottTaylor: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tntspearfish: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for zulumon44: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jeremiahAckermann: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bdaiss: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for alpha4408: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ssravali: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for JLGregg: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for lisatart27: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cruizg93: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jmcasebier: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for kalebjordan1: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for chrisbohn8: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for allraec: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for BaileyEDennis: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for thdotnet: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for plooney81: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for steenzout: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for felixguerrero12: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for dunleavyjack: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for iDataist: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Giana: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for t1ho: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for briancline: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for xXCaulDevsYT: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Ivangonz: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for crislanarafael: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for teuschb: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for AaronV-T: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for nuxusr: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for bell-kevin: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for stefanpenner: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for manuelwebdev: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for YinYang117: cannot access local variable 'merged_df' where it is not associated with a valueError fetching data for JoeyHilton: cannot access local variable 'merged_df' where it is not associated with a value
#
# Error fetching data for subnivean: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for pslattery-wyn: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for zebapy: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for HAZARD6896: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for deepak90: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for missymelisg: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for truemetro: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for andyM-OSI: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for LordZenForce: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for silasmontgomery: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for cbbowman: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for RUJodan: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for khandkerislam: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for fostergn: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Max-c-B: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for joshhting: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for SheldonWangRJT: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for msporny: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for edsnider: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for michaelmang: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for ncosentino: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for daveatnclud: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for NickGerleman: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for amir-zeldes: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for SavoySchuler: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for pappasam: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for edunford: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for wcj365: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for klardotsh: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for neuml: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for gh0straider: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for tommyjr8989: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for kaelapyles: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for biaswesley25: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for savewvwithcode1010: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for aslatter: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Jmeyering: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Yanzheng1998: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for johnpgeipel: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for fanshuaibo: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for CrAzY347: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jastreich: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for BadgersFanFan: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Sharpies: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for JacobHunsberger: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for benholmen: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for allieddata: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for RobertJorgensen: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for Sedavin7326: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for jlschillinger: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for frankiefranoalltheway: cannot access local variable 'merged_df' where it is not associated with a value
# Error fetching data for chrismatko: cannot access local variable 'merged_df' where it is not associated with a value
